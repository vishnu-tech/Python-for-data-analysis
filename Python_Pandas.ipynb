# %% [markdown]
# # PANDAS

# %% [markdown]
# ## What is Pandas?
# Pandas is a Python library, which is used to analyze the data
#
# * It has function for Analyzing, Cleaning, Exploring and Mnipulation of data
# * The "Pandas" Reference Both **Panel Data** and **Python Data Analysis**

# %% [markdown]
# ## What Can Pandas Do?
# Pandas gives you answers about the data. Like:
#
# * Is there a correlation between two or more columns?
# * What is average value?
# * Max value?
# * Min value?
# * Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %% [markdown]
# ## Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# * Pandas can clean messy data sets, and make them readable and relevant.
#
# * Relevant data is very important in data science.

# %%
import pandas as pd
import numpy as np
import os 
workingdirc = os.getcwd()
print(workingdirc)
# Out:
# C:\Users\W2621\Python for Data Analysis

# %%
path = workingdirc + '/test_sales_data.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
df['Unit_Cost'].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
series_variable  = [1,2,3]

# %%
series = pd.Series(series_variable, index = ["x", "y", "z"])

# %%
print(series)
print("The Value is",series["z"])
# Out:
# x    1
# y    2
# z    3
# dtype: int64
# The Value is 3

# %%
data_frame_variable = {"x":[1,2,3],"y":["Cars", "Bike", "Ships"]}

# %%
df = pd.DataFrame(data_frame_variable)
print(df)
# Out:
#    x      y
# 0  1   Cars
# 1  2   Bike
# 2  3  Ships

# %%
series_variable_key_pair = {"data1": 567,
                   "data2": 786,
                   "data3": 758}
data = pd.Series(series_variable_key_pair, index = ["data1", "data2"])
print(data)
# Out:
# data1    567
# data2    786
# dtype: int64

# %%
data_frame_variable = {"x":[1,2,3],
                       "y":["Cars", "Bike", "Ships"]}
df = pd.DataFrame(data_frame_variable)
print(df)
# Out:
#    x      y
# 0  1   Cars
# 1  2   Bike
# 2  3  Ships

# %% [markdown]
# # Series and Data Frame

# %% [markdown]
# ## Series

# %%
data = [45, 787, 43]
df_series = pd.Series(data)

# %%
# print(df_series)
df_series
# df_series_index = pd.Series(data, index = ["obj1", "obj2", "obj3"])
# print(df_series_index)
# Out:
# 0     45
# 1    787
# 2     43
# dtype: int64

# %% [markdown]
# ## Series Object / Keys

# %%
data = {"obj1":"BMW", "obj2":"Benz","obj3":"Audi"}
df_series = pd.Series(data)

# %%
print(df_series)
# Out:
# obj1     BMW
# obj2    Benz
# obj3    Audi
# dtype: object

# %%
#Indexing with object on series
data_series = {"Car1":"BMW", "Car2":"Audi", "Car3":"Bently"}
data = pd.Series(data_series)

# %%
data = pd.Series(data_series, index = ["Car1", "Car2"])
data
# Out:
# Car1     BMW
# Car2    Audi
# dtype: object

# %% [markdown]
# ## Data Frame

# %%
data = {"cars":["BMW", "Audi", "Benz"], "bike":["Ninja", "BMW", "Ducati"]}
data_dataframe = pd.DataFrame(data)
data_dataframe
# Out:
#    cars    bike
# 0   BMW   Ninja
# 1  Audi     BMW
# 2  Benz  Ducati

# %% [markdown]
# ## Locate an Particular Row

# %%
data_dataframe.loc[0]
# Out:
# cars      BMW
# bike    Ninja
# Name: 0, dtype: object

# %%
print(data_dataframe.loc[[1,2]])
# Out:
#    cars    bike
# 1  Audi     BMW
# 2  Benz  Ducati

# %%
data_dataframe = pd.DataFrame(data, index = ["Model1", "Model2", "Model3"])
data_dataframe
# Out:
#         cars    bike
# Model1   BMW   Ninja
# Model2  Audi     BMW
# Model3  Benz  Ducati

# %%
data_dataframe.loc["Model2"]
# Out:
# cars    Audi
# bike     BMW
# Name: Model2, dtype: object

# %% [markdown]
# # JSON and CSV

# %% [markdown]
# ## CSV

# %%
data = pd.read_csv("test_sales_data.csv")
# to_string() to print the entier data frame
print(data.to_string())
# print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
    "128":466.4,
    "129":384.0,
    "130":342.5,
    "131":357.5,
    "132":335.0,
    "133":327.5,
    "134":339.0,
    "135":189.0,
    "136":317.7,
    "137":318.0,
    "138":308.0,
    "139":222.4,
    "140":390.0,
    "141":"null",
    "142":250.4,
    "143":335.4,
    "144":470.2,
    "145":270.8,
    "146":400.0,
    "147":361.9,
    "148":185.0,
    "149":409.4,
    "150":343.0,
    "151":353.2,
    "152":374.0,
    "153":275.8,
    "154":328.0,
    "155":368.5,
    "156":270.4,
    "157":270.4,
    "158":382.8,
    "159":240.9,
    "160":250.4,
    "161":260.4,
    "162":270.0,
    "163":280.9,
    "164":290.8,
    "165":300.4,
    "166":310.2,
    "167":320.4,
    "168":330.4
  }
}

data_json = pd.DataFrame(data)
data_json
# Out:
#      Duration  Pulse  Maxpulse Calories
# 0          60    110       130    409.1
# 1          60    117       145      479
# 2          60    103       135      340
# 3          45    109       175    282.4
# 4          45    117       148      406
# ..        ...    ...       ...      ...
# 164        60    105       140    290.8
# 165        60    110       145    300.4
# 166        60    115       145    310.2
# 167        75    120       150    320.4
# 168        75    125       150    330.4
#
# [169 rows x 4 columns]

# %%
data_csv = pd.read_csv("test_sales_data.csv")

# %%
data_csv.head(10)
# The head() returns only top 5 rows in case of no values given
data_csv.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
data_csv.tail(10)
# The tail() returns only last 5 rows in case of no values given
data_csv.tail()
# Out:
#               Date  Day  Month  Year  Customer_Age       Age_Group  \
# 113031  2016-04-12   12  April  2016            41  Adults (35-64)
# 113032  2014-04-02    2  April  2014            18     Youth (<25)
# 113033  2016-04-02    2  April  2016            18     Youth (<25)
# 113034  2014-03-04    4  March  2014            37  Adults (35-64)
# 113035  2016-03-04    4  March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country          State Product_Category  \
# 113031               M  United Kingdom        England         Clothing
# 113032               M       Australia     Queensland         Clothing
# 113033               M       Australia     Queensland         Clothing
# 113034               F          France  Seine (Paris)         Clothing
# 113035               F          France  Seine (Paris)         Clothing
#
#        Sub_Category          Product  Order_Quantity  Unit_Cost  Unit_Price  \
# ...

# %%
# Gives information about the dataset
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data_excel = pd.read_excel('Mall_Customers.xlsx')
data_excel
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                  15                    39.0
# 1             2    Male  21.0                  15                    81.0
# 2             3  Female  20.0                  16                     6.0
# 3             4  Female  23.0                  16                    77.0
# 4             5  Female  31.0                  17                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0                 120                    79.0
# 196         197  Female  45.0                 126                    28.0
# 197         198    Male  32.0                 126                    74.0
# 198         199    Male  32.0                 137                    18.0
# 199         200    Male  30.0                 137                    83.0
#
# [200 rows x 5 columns]

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data_excel = pd.read_excel('Mall_Customers.xlsx')

# %%
# print(data_excel)
# changedirectory = os.getcwd()
# # print(changedirectory)
# path = changedirectory + '/Mall_Customers.xlsx'
# data_excel = pd.read_excel(path)
print(data_excel)
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                  15                    39.0
# 1             2    Male  21.0                  15                    81.0
# 2             3  Female  20.0                  16                     6.0
# 3             4  Female  23.0                  16                    77.0
# 4             5  Female  31.0                  17                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0                 120                    79.0
# 196         197  Female  45.0                 126                    28.0
# 197         198    Male  32.0                 126                    74.0
# 198         199    Male  32.0                 137                    18.0
# 199         200    Male  30.0                 137                    83.0
#
# [200 rows x 5 columns]

# %%
data_excel
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                  15                    39.0
# 1             2    Male  21.0                  15                    81.0
# 2             3  Female  20.0                  16                     6.0
# 3             4  Female  23.0                  16                    77.0
# 4             5  Female  31.0                  17                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0                 120                    79.0
# 196         197  Female  45.0                 126                    28.0
# 197         198    Male  32.0                 126                    74.0
# 198         199    Male  32.0                 137                    18.0
# 199         200    Male  30.0                 137                    83.0
#
# [200 rows x 5 columns]

# %%
data_excel.shape
# Out:
# (200, 5)

# %%
data_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     199 non-null    float64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  199 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 7.9+ KB

# %%
data_excel.head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                  15                    39.0
# 1           2    Male  21.0                  15                    81.0
# 2           3  Female  20.0                  16                     6.0
# 3           4  Female  23.0                  16                    77.0
# 4           5  Female  31.0                  17                    40.0

# %%
data_excel.tail()
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female  35.0                 120                    79.0
# 196         197  Female  45.0                 126                    28.0
# 197         198    Male  32.0                 126                    74.0
# 198         199    Male  32.0                 137                    18.0
# 199         200    Male  30.0                 137                    83.0

# %%
data_excel.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  199.000000          200.000000              199.000000
# mean   100.500000   38.844221           60.560000               50.175879
# std     57.879185   14.003999           26.264721               25.886392
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.500000           41.500000               34.500000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data_excel['Age'].describe()
# Out:
# count    199.000000
# mean      38.844221
# std       14.003999
# min       18.000000
# 25%       28.500000
# 50%       36.000000
# 75%       49.000000
# max       70.000000
# Name: Age, dtype: float64

# %%
data_excel.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026718            0.977548
# Age                      -0.026718  1.000000           -0.012389
# Annual Income (k$)        0.977548 -0.012389            1.000000
# Spending Score (1-100)    0.014477 -0.327579            0.010432
#
#                         Spending Score (1-100)
# CustomerID                            0.014477
# Age                                  -0.327579
# Annual Income (k$)                    0.010432
# Spending Score (1-100)                1.000000

# %%
data_excel.to_string()
# Out:
# '     CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)\n0             1    Male  19.0                  15                    39.0\n1             2    Male  21.0                  15                    81.0\n2             3  Female  20.0                  16                     6.0\n3             4  Female  23.0                  16                    77.0\n4             5  Female  31.0                  17                    40.0\n5             6  Female  22.0                  17                    76.0\n6             7  Female  35.0                  18                     6.0\n7             8  Female  23.0                  18                    94.0\n8             9    Male  64.0                  19                     3.0\n9            10  Female  30.0                  19                    72.0\n10           11    Male  67.0                  19                    14.0\n11           12  Female  35.0                  19                    99.0\n12           13  Femal
# ...

# %%
# dropna() drops the empty cell and this By default, the dropna() method returns a new DataFrame, and will not change the original.
data_excel_cleaned = data_excel.dropna()
# If you want to change the original DataFrame, use the inplace = True argument:
data_excel.dropna(inplace = True)

# %%
data_excel_cleaned
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                  15                    39.0
# 1             2    Male  21.0                  15                    81.0
# 2             3  Female  20.0                  16                     6.0
# 3             4  Female  23.0                  16                    77.0
# 4             5  Female  31.0                  17                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0                 120                    79.0
# 196         197  Female  45.0                 126                    28.0
# 197         198    Male  32.0                 126                    74.0
# 198         199    Male  32.0                 137                    18.0
# 199         200    Male  30.0                 137                    83.0
#
# [198 rows x 5 columns]

# %%
data_excel.dropna(inplace = True)

# %%
data_excel
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                  15                    39.0
# 1             2    Male  21.0                  15                    81.0
# 2             3  Female  20.0                  16                     6.0
# 3             4  Female  23.0                  16                    77.0
# 4             5  Female  31.0                  17                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0                 120                    79.0
# 196         197  Female  45.0                 126                    28.0
# 197         198    Male  32.0                 126                    74.0
# 198         199    Male  32.0                 137                    18.0
# 199         200    Male  30.0                 137                    83.0
#
# [198 rows x 5 columns]

# %%
# fillna() This way you do not have to delete entire rows just because of some empty cells
data_excel.fillna(30, inplace = True)
# Replace Only For Specified Columns
data_excel['Age'].fillna(30, inplace = True)

# %% [markdown]
# # Mean, Median, Mode

# %%
# MEAN
x = data_excel['Age'].mean()
print("The Mean is",x)
data_excel['Age'].fillna(x, inplace = True)
# Out:
# The Mean is 38.94444444444444

# %%
# MEDIAN
x = data_excel['Age'].median()
print('The Median is',x)
data_excel['Age'].fillna(x, inplace = True)
# Out:
# The Median is 36.0

# %%
# MODE
x = data_excel['Age'].mode()[0]
print('The Mode is', x)
data_excel['Age'].fillna(x, inplace = True)
# Out:
# The Mode is 32.0

# %%
# converting Date in Pandas
# data_excel['date'] = pd.to_datetime(data_excel['date']) # Example

# %%
# In case of dropna() with respect to particular coulumn
data_excel.dropna(subset = ['Age'], inplace = True)

# %%
# Replacing the wrong data with correct values
data_excel.loc[1, 'Age'] = 23
data_excel.loc[1]
# Out:
# CustomerID                   2
# Gender                    Male
# Age                         23
# Annual Income (k$)          15
# Spending Score (1-100)      81
# Name: 1, dtype: object

# %%
data_excel.head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                  15                    39.0
# 1           2    Male  23.0                  15                    81.0
# 2           3  Female  20.0                  16                     6.0
# 3           4  Female  23.0                  16                    77.0
# 4           5  Female  31.0                  17                    40.0

# %%
# In case of handaling large data set loop can be used 
for x in data_excel.index:
    if data_excel.loc[x, 'Age'] > 45:
        data_excel.loc[x, 'Age'] = 60

# %%
data_excel.head(60)
# Out:
#     CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male  19.0                  15                    39.0
# 1            2    Male  23.0                  15                    81.0
# 2            3  Female  20.0                  16                     6.0
# 3            4  Female  23.0                  16                    77.0
# 4            5  Female  31.0                  17                    40.0
# 5            6  Female  22.0                  17                    76.0
# 6            7  Female  35.0                  18                     6.0
# 7            8  Female  23.0                  18                    94.0
# 8            9    Male  60.0                  19                     3.0
# 9           10  Female  30.0                  19                    72.0
# 10          11    Male  60.0                  19                    14.0
# 11          12  Female  35.0                  19                    99.0
# ...

# %%
# Removing the rows that contains wrong data
for x in data_excel.index:
    if data_excel.loc[x, 'Age'] > 30:
        data_excel.drop(x, inplace = True)

# %%
data_excel
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                  15                    39.0
# 1             2    Male  23.0                  15                    81.0
# 2             3  Female  20.0                  16                     6.0
# 3             4  Female  23.0                  16                    77.0
# 5             6  Female  22.0                  17                    76.0
# ..          ...     ...   ...                 ...                     ...
# 177         178    Male  27.0                  88                    69.0
# 183         184  Female  29.0                  98                    88.0
# 185         186    Male  30.0                  99                    97.0
# 187         188    Male  28.0                 101                    68.0
# 199         200    Male  30.0                 137                    83.0
#
# [61 rows x 5 columns]

# %%
# To check for the duplicates duplicated() is used on which returns True or False
# If it has the duplicates it states True else Fasle
data_excel.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
#        ...
# 177    False
# 183    False
# 185    False
# 187    False
# 199    False
# Length: 61, dtype: bool

# %%
# In order to remove the duplicates drop_duplicates() is used
data_excel.drop_duplicates(inplace = True)
#dThe (inplace = True) will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame

# %%
data_excel.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000  0.369799            0.979453
# Age                       0.369799  1.000000            0.372694
# Annual Income (k$)        0.979453  0.372694            1.000000
# Spending Score (1-100)   -0.093828  0.418371           -0.076253
#
#                         Spending Score (1-100)
# CustomerID                           -0.093828
# Age                                   0.418371
# Annual Income (k$)                   -0.076253
# Spending Score (1-100)                1.000000

# %%
import sys
import matplotlib.pyplot as plt

# %%
# Scatter Plot
data_excel.plot(kind = 'scatter', x = 'Age', y = 'Annual Income (k$)' )

# %%
# Histogram requires only one column to check the frequency
data_excel['Age'].plot(kind = 'hist')

# %%
# Readinf Data when the dates Formats to remain same 
data = pd.read_csv('test_sales_data.csv', parse_dates = ['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...
